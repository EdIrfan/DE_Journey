# %% [markdown]
# ## **Boiler Plate**

# %%
import os
from dotenv import load_dotenv
from langchain_openrouter import ChatOpenRouter

load_dotenv(dotenv_path="../.env",override=True)

api_key=os.getenv("OPENROUTER_API_KEY")
if not api_key:
    raise RuntimeError("OPENROUTER_API_KEY is missing from .env")

llm = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash-0731",
    api_key=api_key,
    temperature=0,
    max_tokens=500,
)

# %% [markdown]
# ## **Simple**

# %%
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage

my_messages = [
    HumanMessage(content="Tell me a fun fact bro"),
    SystemMessage(content="Align yourself with a gen-z assistant who answers in fun way")
]

llm.invoke(my_messages).content
# Out:
# 'Bet you didn’t know this: Octopuses have **three hearts**, and two of them actually *stop beating* when they swim. So basically, they choose cardio over circulation. Absolute mood. 🐙💔'

# %% [markdown]
# ## **Little Complex with Prompt**

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a GenZ assistant.Be funny"),
    ("user","Write a fun fact about {topic}")
])

user_input = input("Topic name")

ready_prompt = prompt_template.invoke({"topic":user_input})

llm.invoke(ready_prompt.messages).content
# Out:
# 'Fun fact: apples are 25% air, which is why they float. So if you ever see an apple just vibing in a pool, it’s not drowning—it’s literally living its best life. 🍎💦'
