# %%
import os
from dotenv import load_dotenv
from langchain_openrouter import ChatOpenRouter

load_dotenv(dotenv_path="../.env",override=True)

api_key=os.getenv("OPENROUTER_API_KEY")
if not api_key:
    raise RuntimeError("OPENROUTER_API_KEY is missing from .env")

llm = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash-0731",
    api_key=api_key,
    temperature=0,
    max_tokens=500,
)
# Out:
# /home/irfanxlin/GitHub/DE_JourneyTracker/DE_Journey/Sprints/Custom_Sprint7_Langchain_tutorial/.venv/lib/python3.14/site-packages/langchain_core/utils/pydantic.py:42: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %%
# print(llm.invoke("Tell me a fun fact").content)
# Out:
# Here’s a fun fact: Octopuses have three hearts, and two of them stop beating when they swim. That’s why they prefer crawling along the ocean floor — swimming is literally more tiring for their hearts! 🐙
